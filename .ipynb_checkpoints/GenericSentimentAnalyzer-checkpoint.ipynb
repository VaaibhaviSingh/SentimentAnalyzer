# %%
# import necessary libraries
import pandas as pd
import numpy as np
import csv

# %%
# import data for training and testing from csv file 
data = pd.read_csv('train.csv', error_bad_lines=False)
data.columns = ['ID', 'Sentiment', 'Tweet']
data = data.drop(['ID'], axis=1)
data
# Out:
#        Sentiment                                              Tweet
# 0              0                       is so sad for my APL frie...
# 1              0                     I missed the New Moon trail...
# 2              1                            omg its already 7:30 :O
# 3              0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4              0           i think mi bf is cheating on me!!!   ...
# 5              0                  or i just worry too much?
# 6              1                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7              0         Sunny Again        Work Tomorrow  :-|  ...
# 8              1        handed in my uniform today . i miss you ...
# 9              1           hmmmm.... i wonder how she my number @-)
# 10             0                      I must think about positive..
# 11             1        thanks to all the haters up in my face a...
# 12             0                     this weekend has sucked so far
# 13             0             jb isnt showing in australia any more!
# 14             0                               ok thats it you win.
# 15             0      &lt;-------- This is the way i feel right ...
# 16             0      awhhe man.... I'm completely useless rt no...
# 17             1      Feeling strangely fine. Now I'm gonna go l...
# 18             0       HUGE roll of thunder just now...SO scary!!!!
# 19             0      I just cut my beard off. It's only been gr...
# 20             0                               Very sad about Iran.
# 21             0                                      wompppp wompp
# 22             1      You're the only one who can see this cause...
# 23             0     &lt;---Sad level is 3. I was writing a mass...
# 24             0     ...  Headed to Hospitol : Had to pull out o...
# 25             0     BoRinG   ): whats wrong with him??     Plea...
# 26             0     can't be bothered. i wish i could spend the...
# 27             0     Feeeling like shit right now. I really want...
# 28             1              goodbye exams, HELLO ALCOHOL TONIGHT
# 29             0     I didn't realize it was THAT deep. Geez giv...
# ...          ...                                                ...
# 99959          0  @CT415 @UCLA_Bruin  it made me sad too!  that ...
# 99960          1  @CT415 I agree. I think they all have that fet...
# 99961          0  @ct415 I hope it's not too serious of an injur...
# 99962          0  @ctabita if it's any consolation, this weekend...
# 99963          1                        @ctayah got your back, yo!
# 99964          1  @ctaylor0127 I can't wait to see that movie. E...
# 99965          1  @ctaylor10127 @smelby I am excited and a littl...
# 99966          0  @ctb1221 yeah  sorry.going to a concert that n...
# 99967          1  @ctcash @buildingateam @diabetescure @chocolat...
# 99968          1  @ctdesign87 im so glad you went to china town ...
# 99969          0                                 @CTerry1985  Sorry
# 99970          0                @CTerry1985 damn it, dont have sky
# 99971          0  @CTerry1985 That's the thing; the new raft of ...
# 99972          1                                          @cthagod
# 99973          1                              @ctham  #FollowFriday
# 99974          0  @ctham #awaresg You are not wrong. But from a ...
# 99975          0  @ctham @mommyfizz cuz you big burly man.  haha...
# 99976          1  @ctham @Wilsurn Trying to get a wider range of...
# 99977          1    @ctham Haha I love the passion in your support
# 99978          1  @cthulhullahoop That sucks...I like living in ...
# 99979          1  @cunningstunts till i can go home been here ti...
# 99980          1         @cunningstunts22 afternoon jim hows you  x
# 99981          0  @cup_a_tea The foot is really bad. Like the wo...
# 99982          1  @Cup_Of_Katy Have fun doing health &amp; safet...
# 99983          0  @cupati It took me waaay too long to get your ...
# 99984          0  @Cupcake  seems like a repeating problem   hop...
# 99985          1  @cupcake__ arrrr we both replied to each other...
# 99986          0                     @CuPcAkE_2120 ya i thought so
# 99987          1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...
# 99988          1                    @cupcake_kayla haha yes you do
#
# [99989 rows x 2 columns]

# %%
# get the number of positive and negative tweets 
pos_tweets = data['Sentiment'][data.Sentiment == 0]
neg_tweets = data['Sentiment'][data.Sentiment == 1]

print('Number of positve tweets are:  {}'.format(len(pos_tweets)))
print('Number of negative tweets are: {}'.format(len(neg_tweets)))
print('Total length of the data is:   {}'.format(data.shape[0]))
# Out:
# Number of positve tweets are:  43532
# Number of negative tweets are: 56457
# Total length of the data is:   99989

# %%
# get word count per sentence column
def word_count(sentence):
    return len(sentence.split())
    
data['wordCount'] = data['Tweet'].apply(word_count)
data
# Out:
#        Sentiment                                              Tweet  wordCount
# 0              0                       is so sad for my APL frie...          7
# 1              0                     I missed the New Moon trail...          6
# 2              1                            omg its already 7:30 :O          5
# 3              0            .. Omgaga. Im sooo  im gunna CRy. I'...         25
# 4              0           i think mi bf is cheating on me!!!   ...          9
# 5              0                  or i just worry too much?                  6
# 6              1                 Juuuuuuuuuuuuuuuuussssst Chillin!!          2
# 7              0         Sunny Again        Work Tomorrow  :-|  ...          7
# 8              1        handed in my uniform today . i miss you ...         10
# 9              1           hmmmm.... i wonder how she my number @-)          8
# 10             0                      I must think about positive..          5
# 11             1        thanks to all the haters up in my face a...         12
# 12             0                     this weekend has sucked so far          6
# 13             0             jb isnt showing in australia any more!          7
# 14             0                               ok thats it you win.          5
# 15             0      &lt;-------- This is the way i feel right ...          9
# 16             0      awhhe man.... I'm completely useless rt no...         15
# 17             1      Feeling strangely fine. Now I'm gonna go l...         13
# 18             0       HUGE roll of thunder just now...SO scary!!!!          7
# 19             0      I just cut my beard off. It's only been gr...         26
# 20             0                               Very sad about Iran.          4
# 21             0                                      wompppp wompp          2
# 22             1      You're the only one who can see this cause...         23
# 23             0     &lt;---Sad level is 3. I was writing a mass...         26
# 24             0     ...  Headed to Hospitol : Had to pull out o...         25
# 25             0     BoRinG   ): whats wrong with him??     Plea...         10
# 26             0     can't be bothered. i wish i could spend the...         21
# 27             0     Feeeling like shit right now. I really want...         24
# 28             1              goodbye exams, HELLO ALCOHOL TONIGHT           5
# 29             0     I didn't realize it was THAT deep. Geez giv...         14
# ...          ...                                                ...        ...
# 99959          0  @CT415 @UCLA_Bruin  it made me sad too!  that ...         12
# 99960          1  @CT415 I agree. I think they all have that fet...         11
# 99961          0  @ct415 I hope it's not too serious of an injur...         17
# 99962          0  @ctabita if it's any consolation, this weekend...         14
# 99963          1                        @ctayah got your back, yo!           5
# 99964          1  @ctaylor0127 I can't wait to see that movie. E...          9
# 99965          1  @ctaylor10127 @smelby I am excited and a littl...         12
# 99966          0  @ctb1221 yeah  sorry.going to a concert that n...         10
# 99967          1  @ctcash @buildingateam @diabetescure @chocolat...         15
# 99968          1  @ctdesign87 im so glad you went to china town ...         20
# 99969          0                                 @CTerry1985  Sorry          2
# 99970          0                @CTerry1985 damn it, dont have sky           6
# 99971          0  @CTerry1985 That's the thing; the new raft of ...         18
# 99972          1                                          @cthagod           1
# 99973          1                              @ctham  #FollowFriday          2
# 99974          0  @ctham #awaresg You are not wrong. But from a ...         27
# 99975          0  @ctham @mommyfizz cuz you big burly man.  haha...          8
# 99976          1  @ctham @Wilsurn Trying to get a wider range of...         20
# 99977          1    @ctham Haha I love the passion in your support           9
# 99978          1  @cthulhullahoop That sucks...I like living in ...         15
# 99979          1  @cunningstunts till i can go home been here ti...         11
# 99980          1         @cunningstunts22 afternoon jim hows you  x          6
# 99981          0  @cup_a_tea The foot is really bad. Like the wo...         18
# 99982          1  @Cup_Of_Katy Have fun doing health &amp; safet...         15
# 99983          0  @cupati It took me waaay too long to get your ...         19
# 99984          0  @Cupcake  seems like a repeating problem   hop...         12
# 99985          1  @cupcake__ arrrr we both replied to each other...         26
# 99986          0                     @CuPcAkE_2120 ya i thought so           5
# 99987          1  @Cupcake_Dollie Yes. Yes. I'm glad you had mor...         11
# 99988          1                    @cupcake_kayla haha yes you do           5
#
# [99989 rows x 3 columns]

# %%
# plot word count distribution for both positive and negative sentiments against frequency of tweets  
import matplotlib.pyplot as plt

x = data['wordCount'][data.Sentiment == 1]
y = data['wordCount'][data.Sentiment == 0]
plt.figure(figsize=(12,6))
plt.xlim(0,45)
plt.xlabel('Word Count')
plt.ylabel('Frequency')
g = plt.hist([x, y], color=['g','y'], alpha=0.8, label=['positive','negative'])
plt.legend(loc='upper right')

# %%
# split 33% data for test from the total data 

from sklearn.model_selection import train_test_split

X = data['Tweet']
y = data['Sentiment']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# get the most common words in training dataset 
from collections import Counter

all_words = []
for line in list(X_train):
    words = line.split()
    for word in words:
        all_words.append(word.lower())
        
Counter(all_words).most_common(10)
# Out:
# [('i', 32761),
#  ('the', 19917),
#  ('to', 19641),
#  ('you', 15683),
#  ('a', 14721),
#  ('and', 10572),
#  ('it', 9450),
#  ('my', 9124),
#  ('for', 8247),
#  ('is', 7829)]

# %%
# plot the word frequency distribution of the first few words
import nltk

plt.figure(figsize=(12,5))
plt.title('Top 25 most common words')
plt.xticks(fontsize=13, rotation=90)
fd = nltk.FreqDist(all_words)
fd.plot(25,cumulative=False)

# %%
list = []
for i in range(1, len(X_train)+1):
    list.append(i)

# %%
# make the dataframe of training data 
data_train = pd.DataFrame()
data_train['Sentiment'] = y_train
data_train['Tweet'] = X_train
data_train = data_train.set_index([list])

# %%
data_train
# Out:
#        Sentiment                                              Tweet
# 1              1  @alekzalatte latte! Welcome to Twitter!!!!!!! ...
# 2              0  @Chaoticshimmer if it was that Paul I would ha...
# 3              0  @aciel Hihihi... udah nyoba UberTwitter belum?...
# 4              0  @Bleakey Dude, it's so true. And the little as...
# 5              0  @barbra77 work nights in a 5* private apartmen...
# 6              0  @BostonTweet all these awesome free things and...
# 7              1  @brod3740 Absolutely! If they can keep it clos...
# 8              0  @ArinIsLove college business has gotten me bus...
# 9              0  @AceMas21 certainly is  more pigeon snorkers??...
# 10             1  @amandabynes I already have, but thanks for th...
# 11             1  @benald Hi I have uploaded 5 completely new Ch...
# 12             1  @aleshajae3t: hi *hugs*  I'm.good and you? Tha...
# 13             1  @coldplay http://twitpic.com/5dbf7 - Great pic...
# 14             0  *sigh* its over  i suppose if it takes more th...
# 15             1                             Am I feeding the Pig'?
# 16             0   wow.  feeling seriously let down by the big g...
# 17             0  @allyhulton don't  about that, no girl should ...
# 18             0  @alexiskn You're staying in the dark unless yo...
# 19             0  @AskCarrieLee CVS is that like a genetic brand...
# 20             0  @CookieMondays Sorry to hear about your Grandm...
# 21             1  @1txsage1957 Thanks so much for the #follow re...
# 22             1        @atomicskunk I hope you reach it!  *cheers*
# 23             0  @Alcedine sorry if I distracted you from remem...
# 24             1    @astrylnaut yeah talking to you was too boring
# 25             0   @alwayscandace heyyyyyy. i miss you. come chat.
# 26             0  #dontyouhate when people try to spray perfume ...
# 27             0                    @bbcrad I miss you by the way.
# 28             1  @Brandesme No this is not redirects, this is j...
# 29             1         @anthonysarino please give me that key...
# 30             0  @AllyAyr and I seem to have lost one ....oh well
# ...          ...                                                ...
# 66963          1   I just don't know how to begin this twitter t...
# 66964          1  .@fnelson tell them not to hate Twitter, but t...
# 66965          0  @astynes Count yrself VERY lucky! It's so frus...
# 66966          1  @614grapevine Can't wait to give Jeni's icecre...
# 66967          1                      @BastetAsshur Your too kind!
# 66968          1  @angeladriana Congratulations!! I'll be prayin...
# 66969          0                            @aj_dc  love you cuz!!!
# 66970          1  @Cebu777 aww cool! hahaha Sheepz. baka magka i...
# 66971          1  @babygirlparis That's good  I am happy that yo...
# 66972          1         @caspain i know i'm late.....but THANKS!!
# 66973          1         #follow @spreadingjoy the name say it all
# 66974          1  @amyjackson10 hahaha...good thing about Twitte...
# 66975          1                 @brandonskellham fuck you asshole
# 66976          1  @blogginforbiz No prob ... got lost, got hungr...
# 66977          1  @Beverleyknight  really? ur a brave lady walki...
# 66978          1   @LisaBarone If, thru the miracle of modern sc...
# 66979          1  @brajana well.. that is up to Jess. Is there a...
# 66980          0  @brlittle Ugh... this interface is already so ...
# 66981          1          @andrewfaith pick me, i m free of charge
# 66982          1                                        .HOUSEEEE.
# 66983          1  @bibs4drips  MorningEdith! Hope ur  sunday is ...
# 66984          1  @ankita_gaba evrytime i listen to the name of ...
# 66985          1  @charly_murg lolol, well a lot of places are b...
# 66986          0                     @alina79ro yap. thats the one
# 66987          0  @chelseyann226 Truth hurts...you're so indenia...
# 66988          0  #dontyouhate when you try to be sumbody everyt...
# 66989          1  @azamedia Are you really???? Bonus! We can be ...
# 66990          0  @Bwgan s'not fair  I'm going to do overtime af...
# 66991          0   Dinara lost again in Roland Garros. Why the S...
# 66992          0       *yawn* But that's no excuse not to head out
#
# [66992 rows x 2 columns]

# %%
list2 = []
for i in range(1, len(X_test)+1):
    list2.append(i)

# %%
# make the dataframe of test data 
data_test = pd.DataFrame()
data_test['Sentiment'] = y_test
data_test['Tweet'] = X_test
data_test = data_test.set_index([list2])

# %%
data_test
# Out:
#        Sentiment                                              Tweet
# 1              1                               @Allieandra wheeee!
# 2              1  @a02toyota Thank you for the FF! Good to meet ya
# 3              0  @ electricbath Eewwww. Gross! So sorry hayward...
# 4              1  #followfriday - I'm a little late, but here's ...
# 5              1  #icanhelp in shopping (deals), personal assist...
# 6              0               broken hearts will heal with time...
# 7              0  ..I've already listened to all the S4 commenta...
# 8              1  &quot;Everybody make mistakes.&quot; I'm gonna...
# 9              1  #I Believe...that if you smile at someone, fri...
# 10             0  @andreacFOD I think I'm done at twitterland to...
# 11             1             @alex_mauricio goodnight mr. Mauricio
# 12             1  @Bffleck Going to Italy and Portugal...But fir...
# 13             0                   @aranger   down with iPhone! ;-)
# 14             0  :-O it's not even 8am yet and the temperature ...
# 15             1                       @changroy no he's the actor
# 16             1  @ajruckman That is why I love using TweetDeck!...
# 17             0  #smx so bummed I cannot be there ... next year...
# 18             0  #WeAreStupid what worries me most, these are g...
# 19             0           #squarespace because I forgot yesterday
# 20             1  @abphd how much u wanna bet your own bed isn't...
# 21             0                                      @ButifulMess
# 22             1  @babytaco Really? That's wassup! Write sumthin...
# 23             1                          #myweakness Chris Brown!
# 24             1             @Born_4_Broadway Ya maybe next summer
# 25             1         @_Maro thats because u had a long weekend
# 26             1  @afectado if it is summer it is good weather b...
# 27             1  @angryfaggot, Whered you end up going? I staye...
# 28             1  @abhijitkadle @gargamit100 @amitgautam  was wa...
# 29             0  @clarebiddle what questions did you do?...i fo...
# 30             0  @bernhardstacher At £450 as there is currently...
# ...          ...                                                ...
# 32968          0   i want to b happy n content. tell me hw. - ht...
# 32969          1  @abpersonality maybe it's not charging because...
# 32970          0                  i dont wanna do this im gunna cry
# 32971          0  @ceciliabedelia go team  can't wait for reunionnn
# 32972          0  @aadisht I slept at 2:30 and got up at 8:30, m...
# 32973          0  ...sick doggies can change a well planned day ...
# 32974          0         ... that means no mor tweets! laaammmeeee
# 32975          1  @batagur  I wasn't going to be the one to say ...
# 32976          1  @106andpark I would say R. Kelly the one and o...
# 32977          0  @AntoneellaP  Aww   I am  saad,  very sad     ...
# 32978          1  @123lottie AWWWWW you must have the patience o...
# 32979          1  @4mat_scenemusic @therioman @danbee @jamesmb T...
# 32980          0  @abiFACE aw  im gonna miss ya.. and i won even...
# 32981          1                             @_spell Thanks a lot!
# 32982          0  @chefashbabe OMG! Don't remind me.  On the +ve...
# 32983          1  @CollingsA in the words of @EdwynCollins 'it's...
# 32984          1  @citychains ohh, right. lol, i got it, it's pr...
# 32985          1  @_Irene_Adler buh bye pretty lady, cheers for ...
# 32986          1   @angusups Just seeing if anyone was still awake
# 32987          0  @Choze r u ok hun..i saw ur myspace a lil whil...
# 32988          0                                .im gaining weight
# 32989          0                    @Ainse About ten minutes ago.
# 32990          1  @ayagil it takes a while specially if it's ur ...
# 32991          1  @bradiewebbstack LOL. im having a reallyyy cra...
# 32992          1                                         @b3auty81
# 32993          1  @aville20 no I have not but I will seriously l...
# 32994          0                            no one calls me anymore
# 32995          0  @Bnice910 hurt my heart. typos are powerful if...
# 32996          1  @ChristineMLe oh yeah  you're lucky you got to...
# 32997          1  @cocktaildelight --&gt; why does everyone seem...
#
# [32997 rows x 2 columns]

# %%
# helper function to clean tweets
import re 
from string import punctuation

def processTweet(tweet):
    # remove HTML special entities (e.g. &amp;)
    tweet = re.sub(r'\&\w*;','', tweet)
    # convert @username to AT_USER
    tweet = re.sub('@[^\s]+','',tweet)
    # remove tickers
    tweet = re.sub(r'\$\w','',tweet)
    # convert tweet to lowercase
    tweet = tweet.lower()
    # remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*\/\w*','',tweet)
    # remove hashtags
    tweet = re.sub(r'#\w*','',tweet)
    # remove punctuation and split 's, 't, 've with a space for filter
    tweet = re.sub(r'['+ punctuation.replace('@', '') +']+', ' ', tweet)
    # remove words with two or fewer letters
    tweet = re.sub(r'\b\w{1,2}\b','', tweet)
    # remove whitespace (including new line characters)
    tweet = re.sub(r'\s\s+', ' ', tweet)
    # remove single space remaining at the front of the tweet.
    tweet = tweet.lstrip(' ') 
    # remove characters beyond Basic Multilingual Plane (BMP) of Unicode:
    tweet = ''.join(c for c in tweet if c <= '\uFFFF') 
    return tweet

# %%
# clean traing and test dataframe's text column 
data_train['Tweet'] = data_train['Tweet'].apply(processTweet)
data_test['Tweet'] = data_test['Tweet'].apply(processTweet)

# %%
data_train
# Out:
#        Sentiment                                              Tweet
# 1              1                         latte welcome twitter yay
# 2              0  was that paul would have ass already line see ...
# 3              0  hihihi udah nyoba ubertwitter belum atau tweet...
# 4              0  dude true and the little asian ladies always r...
# 5              0  work nights private apartments leeds yorkshire...
# 6              0  all these awesome free things and desire outsi...
# 7              1  absolutely they can keep close they have chanc...
# 8              0  college business has gotten busy while school ...
# 9              0                certainly more pigeon snorkers lol
# 10             1  already have but thanks for the reminder amand...
# 11             1  have uploaded completely new chinese lessons w...
# 12             1  hugs good and you that birdie comment cute wen...
# 13             1  great picture chris looks great hope you guys ...
# 14             0  sigh its over suppose takes more then min lose...
# 15             1                                   feeding the pig
# 16             0       wow feeling seriously let down the big guys
# 17             0         don about that girl should endure meeting
# 18             0  you staying the dark unless you can woman and ...
# 19             0  cvs that like genetic brand poor you hubby get...
# 20             0    sorry hear about your grandma sending you hugs
# 21             1                thanks much for the recommendation
# 22             1                             hope you reach cheers
# 23             0             sorry distracted you from remembering
# 24             1                   yeah talking you was too boring
# 25             0                       heyyyyyy miss you come chat
# 26             0  when people try spray perfume cologne over thi...
# 27             0                                  miss you the way
# 28             1  this not redirects this just updating posts ou...
# 29             1                              please give that key
# 30             0                       and seem have lost one well
# ...          ...                                                ...
# 66963          1  just don know how begin this twitter thing any...
# 66964          1     tell them not hate twitter but become twitter
# 66965          0  count yrself very lucky frustrating bots that ...
# 66966          1  can wait give jeni icecream try next time colu...
# 66967          1                                     your too kind
# 66968          1  congratulations praying for you and your baby ...
# 66969          0                                      love you cuz
# 66970          1  aww cool hahaha sheepz baka magka identity cri...
# 66971          1             that good happy that you are happy lol
# 66972          1                              know late but thanks
# 66973          1                                  the name say all
# 66974          1  hahaha good thing about twitter erasing the ev...
# 66975          1                                  fuck you asshole
# 66976          1  prob got lost got hungry found great places ea...
# 66977          1  really brave lady walkin around those lions th...
# 66978          1  thru the miracle modern science bruce and dann...
# 66979          1                well that jess there pony mini pet
# 66980          0  ugh this interface already horrible don know c...
# 66981          1                                  pick free charge
# 66982          1                                          houseeee
# 66983          1  morningedith hope sunday going great like plan...
# 66984          1  evrytime listen the name tat plce reminded moj...
# 66985          1  lolol well lot places are bloody rough these d...
# 66986          0                                 yap thats the one
# 66987          0                      truth hurts you indenial sad
# 66988          0  when you try sumbody everything but nothing yo...
# 66989          1        are you really bonus can new town together
# 66990          0      not fair going overtime after leave lcd fund
# 66991          0  dinara lost again roland garros why the safins...
# 66992          0                 yawn but that excuse not head out
#
# [66992 rows x 2 columns]

# %%
data_test
# Out:
#        Sentiment                                              Tweet
# 1              1                                            wheeee
# 2              1                       thank you for the good meet
# 3              0  @ electricbath eewwww gross sorry hayward hate...
# 4              1  little late but here special shoutout for missus
# 5              1  shopping deals personal assistant event planni...
# 6              0                 broken hearts will heal with time
# 7              0  already listened all the commentary except the...
# 8              1  everybody make mistakes gonna get some sleep b...
# 9              1  believe that you smile someone friend stranger...
# 10             0  think done twitterland too will tweet david on...
# 11             1                                goodnight mauricio
# 12             1  going italy and portugal but first enjoy some ...
# 13             0                                  down with iphone
# 14             0  not even 8am yet and the temperature outside a...
# 15             1                                         the actor
# 16             1  that why love using tweetdeck was showing that...
# 17             0  bummed cannot there next year hope read lot gr...
# 18             0  what worries most these are gov employees from...
# 19             0                          because forgot yesterday
# 20             1    how much wanna bet your own bed isn comfy mine
# 21             0
# 22             1  really that wassup write sumthin for and and w...
# 23             1                                       chris brown
# 24             1                                 maybe next summer
# 25             1                    thats because had long weekend
# 26             1  summer good weather but the previous day was a...
# 27             1  whered you end going stayed watched snl one th...
# 28             1                        was waiting for this tweet
# 29             0  what questions did you found crazy hard aswell...
# 30             0  £450 there currently upgrade option think not ...
# ...          ...                                                ...
# 32968          0                want happy content tell http tweet
# 32969          1  maybe not charging because the outlets are fun...
# 32970          0                          dont wanna this gunna cry
# 32971          0                        team can wait for reunionnn
# 32972          0                          slept and got much worse
# 32973          0  sick doggies can change well planned day heart...
# 32974          0                 that means mor tweets laaammmeeee
# 32975          1                   wasn going the one say anything
# 32976          1             would say kelly the one and only king
# 32977          0          aww saad very sad need you help call you
# 32978          1           awwwww you must have the patience saint
# 32979          1           thank you all for happy birthday wishes
# 32980          0      gonna miss and won even home this summer see
# 32981          1                                        thanks lot
# 32982          0  omg don remind the side had delayed putting th...
# 32983          1    the words the truly detestable summer festival
# 32984          1       ohh right lol got pretty good thanks anyway
# 32985          1  buh bye pretty lady cheers for brightening the...
# 32986          1                just seeing anyone was still awake
# 32987          0  hun saw myspace lil while ago had sent message...
# 32988          0                                    gaining weight
# 32989          0                             about ten minutes ago
# 32990          1  takes while specially 1st time launch your wai...
# 32991          1  lol having reallyyy crao day 2day and would ma...
# 32992          1
# 32993          1  have not but will seriously look into will hav...
# 32994          0                                  one calls anymore
# 32995          0  hurt heart typos are powerful that indeed what...
# 32996          1                yeah you lucky you got watch twice
# 32997          1  why does everyone seem telling that lol everyo...
#
# [32997 rows x 2 columns]

# %%
from wordcloud import WordCloud

# split sentences to get individual words
all_words = []
for line in data_train['Tweet']:
    words = line.split()
    for word in words:
        all_words.append(word.lower())
        
# create a word frequency dictionary
wordfreq = Counter(all_words)

# draw a Word Cloud with word frequencies
wordcloud = WordCloud(width=900, height=500, max_words=500, max_font_size=100, relative_scaling=0.5, colormap='Blues', normalize_plurals=True).generate_from_frequencies(wordfreq)

plt.figure(figsize=(17,14))
plt.title('Word Cloud of training data')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud

# split sentences to get individual words
all_words = []
for line in data_test['Tweet']:
    words = line.split()
    for word in words:
        all_words.append(word.lower())
        
# create a word frequency dictionary
wordfreq = Counter(all_words)

# draw a Word Cloud with word frequencies
wordcloud = WordCloud(width=900, height=500, max_words=500, max_font_size=100, relative_scaling=0.5, colormap='Blues', normalize_plurals=True).generate_from_frequencies(wordfreq)

plt.figure(figsize=(17,14))
plt.title('Word Cloud of test data')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
